# %%
import pandas as pd

# %%
num = {"Name":["Hari","Ram","Jai","Amie"],
       "Age":[20,19,25,27],"Designation":["CEO","HR","Manager","Labour"],
       "Salary":[30000,25000,20000,10000]}

# %%
print(num)
# Out:
# {'Name': ['Hari', 'Ram', 'Jai', 'Amie'], 'Age': [20, 19, 25, 27], 'Designation': ['CEO', 'HR', 'Manager', 'Labour'], 'Salary': [30000, 25000, 20000, 10000]}

# %%
print(pd.DataFrame(num))
# Out:
#    Name  Age Designation  Salary
# 0  Hari   20         CEO   30000
# 1   Ram   19          HR   25000
# 2   Jai   25     Manager   20000
# 3  Amie   27      Labour   10000

# %%
print(pd.Series(num))
# Out:
# Name                 [Hari, Ram, Jai, Amie]
# Age                        [20, 19, 25, 27]
# Designation      [CEO, HR, Manager, Labour]
# Salary         [30000, 25000, 20000, 10000]
# dtype: object

# %%
df = pd.read_csv("C:/Users/Admin/Downloads/employees.csv")

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.tail()
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df.rename(columns = {"First Name":"Name"},inplace = True)

# %%
df.head()
# Out:
#       Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0  Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1   Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2    Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3    Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4    Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.isnull().sum()
# Out:
# Name                  67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.fillna(0,inplace = True)

# %%
df.isnull().sum()
# Out:
# Name                 0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
df['Name']
# Out:
# 0      Douglas
# 1       Thomas
# 2        Maria
# 3        Jerry
# 4        Larry
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: Name, Length: 1000, dtype: object

# %%
df[df['Team'] == 'Finance']
# Out:
#           Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7            0  Female   7/20/2015        10:43 AM   45906   11.598
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 46       Bruce    Male  11/28/2009        10:47 PM  114796    6.796
# ..         ...     ...         ...             ...     ...      ...
# 907  Elizabeth  Female   7/27/1998        11:12 AM  137144   10.081
# 954        Joe    Male   1/19/1980         4:06 PM  119667    1.148
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                   0  Finance
# ...

# %%
df['Salary'] = df['Salary'].apply(lambda x: x + 1)
print(df)
# Out:
#         Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97309    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61934    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130591   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138706    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101005    1.389
# ..       ...     ...         ...             ...     ...      ...
# 995    Henry       0  11/23/2014         6:09 AM  132484   16.655
# 996  Phillip    Male   1/31/1984         6:30 AM   42393   19.675
# 997  Russell    Male   5/20/2013        12:39 PM   96915    1.421
# 998    Larry    Male   4/20/2013         4:45 PM   60501   11.985
# 999   Albert    Male   5/15/2012         6:24 PM  129950   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                     0
# ...

# %%
df.to_csv("output1.csv",index = True)

# %%
df
# Out:
#         Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97309    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61934    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130591   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138706    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101005    1.389
# ..       ...     ...         ...             ...     ...      ...
# 995    Henry       0  11/23/2014         6:09 AM  132484   16.655
# 996  Phillip    Male   1/31/1984         6:30 AM   42393   19.675
# 997  Russell    Male   5/20/2013        12:39 PM   96915    1.421
# 998    Larry    Male   4/20/2013         4:45 PM   60501   11.985
# 999   Albert    Male   5/15/2012         6:24 PM  129950   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                     0
# ...

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
df['Start Date']
# Out:
# 0        8/6/1993
# 1       3/31/1996
# 2       4/23/1993
# 3        3/4/2005
# 4       1/24/1998
#           ...
# 995    11/23/2014
# 996     1/31/1984
# 997     5/20/2013
# 998     4/20/2013
# 999     5/15/2012
# Name: Start Date, Length: 1000, dtype: object

# %%
import matplotlib.pyplot as plt
df['Salary'].plot(kind='bar')
plt.show()

# %%
df.reset_index('Gender',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30760\3539290487.py in <module>
# ----> 1 df.reset_index('Gender',inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6423             if not isinstance(level, (tuple, list)):
#    6424                 level = [level]
# -> 6425             level = [self.index._get_level_number(lev) for lev in level]
#    6426             if len(level) < self.index.nlevels:
#    6427                 new_index = self.index.droplevel(level)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    6423             if not isinstance(level, (tuple, list)):
#    6424                 level = [level]
# -> 6425             level = [self.index._get_level_number(lev) for lev in level]
# ...

# %%
df
# Out:
#         Name  Gender  Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993 2024-08-07 12:42:00   97309    6.945
# 1     Thomas    Male   3/31/1996 2024-08-07 06:53:00   61934    4.170
# 2      Maria  Female   4/23/1993 2024-08-07 11:17:00  130591   11.858
# 3      Jerry    Male    3/4/2005 2024-08-07 13:00:00  138706    9.340
# 4      Larry    Male   1/24/1998 2024-08-07 16:47:00  101005    1.389
# ..       ...     ...         ...                 ...     ...      ...
# 995    Henry       0  11/23/2014 2024-08-07 06:09:00  132484   16.655
# 996  Phillip    Male   1/31/1984 2024-08-07 06:30:00   42393   19.675
# 997  Russell    Male   5/20/2013 2024-08-07 12:39:00   96915    1.421
# 998    Larry    Male   4/20/2013 2024-08-07 16:45:00   60501   11.985
# 999   Albert    Male   5/15/2012 2024-08-07 18:24:00  129950   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
z = df.loc[0]
pd.Series(z)
# Out:
# Name                             Douglas
# Gender                              Male
# Start Date                      8/6/1993
# Last Login Time      2024-08-07 12:42:00
# Salary                             97309
# Bonus %                            6.945
# Senior Management                   True
# Team                           Marketing
# Name: 0, dtype: object

# %%
df.drop(columns ={"Team"},inplace = True)

# %%
df
# Out:
#         Name  Gender  Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993 2024-08-07 12:42:00   97309    6.945
# 1     Thomas    Male   3/31/1996 2024-08-07 06:53:00   61934    4.170
# 2      Maria  Female   4/23/1993 2024-08-07 11:17:00  130591   11.858
# 3      Jerry    Male    3/4/2005 2024-08-07 13:00:00  138706    9.340
# 4      Larry    Male   1/24/1998 2024-08-07 16:47:00  101005    1.389
# ..       ...     ...         ...                 ...     ...      ...
# 995    Henry       0  11/23/2014 2024-08-07 06:09:00  132484   16.655
# 996  Phillip    Male   1/31/1984 2024-08-07 06:30:00   42393   19.675
# 997  Russell    Male   5/20/2013 2024-08-07 12:39:00   96915    1.421
# 998    Larry    Male   4/20/2013 2024-08-07 16:45:00   60501   11.985
# 999   Albert    Male   5/15/2012 2024-08-07 18:24:00  129950   10.169
#
#     Senior Management
# 0                True
# 1                True
# 2               False
# 3                True
# ...

# %%
df.drop(index ={12},inplace = True)

# %%
df
# Out:
#         Name  Gender  Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993 2024-08-07 12:42:00   97309    6.945
# 1     Thomas    Male   3/31/1996 2024-08-07 06:53:00   61934    4.170
# 2      Maria  Female   4/23/1993 2024-08-07 11:17:00  130591   11.858
# 3      Jerry    Male    3/4/2005 2024-08-07 13:00:00  138706    9.340
# 4      Larry    Male   1/24/1998 2024-08-07 16:47:00  101005    1.389
# ..       ...     ...         ...                 ...     ...      ...
# 995    Henry       0  11/23/2014 2024-08-07 06:09:00  132484   16.655
# 996  Phillip    Male   1/31/1984 2024-08-07 06:30:00   42393   19.675
# 997  Russell    Male   5/20/2013 2024-08-07 12:39:00   96915    1.421
# 998    Larry    Male   4/20/2013 2024-08-07 16:45:00   60501   11.985
# 999   Albert    Male   5/15/2012 2024-08-07 18:24:00  129950   10.169
#
#     Senior Management
# 0                True
# 1                True
# 2               False
# 3                True
# ...

# %%
df['Gender'] = df['Gender'].map({'Male': 100000, 'Female': 200000})

# %%
df
# Out:
#         Name    Gender  Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas  100000.0    8/6/1993 2024-08-07 12:42:00   97309    6.945
# 1     Thomas  100000.0   3/31/1996 2024-08-07 06:53:00   61934    4.170
# 2      Maria  200000.0   4/23/1993 2024-08-07 11:17:00  130591   11.858
# 3      Jerry  100000.0    3/4/2005 2024-08-07 13:00:00  138706    9.340
# 4      Larry  100000.0   1/24/1998 2024-08-07 16:47:00  101005    1.389
# ..       ...       ...         ...                 ...     ...      ...
# 995    Henry       NaN  11/23/2014 2024-08-07 06:09:00  132484   16.655
# 996  Phillip  100000.0   1/31/1984 2024-08-07 06:30:00   42393   19.675
# 997  Russell  100000.0   5/20/2013 2024-08-07 12:39:00   96915    1.421
# 998    Larry  100000.0   4/20/2013 2024-08-07 16:45:00   60501   11.985
# 999   Albert  100000.0   5/15/2012 2024-08-07 18:24:00  129950   10.169
#
#     Senior Management
# 0                True
# 1                True
# 2               False
# ...

# %%
df['Name'] = df['Name'].str.upper()

# %%
df
# Out:
#         Name    Gender  Start Date     Last Login Time  Salary  Bonus %  \
# 0    DOUGLAS  100000.0    8/6/1993 2024-08-07 12:42:00   97309    6.945
# 1     THOMAS  100000.0   3/31/1996 2024-08-07 06:53:00   61934    4.170
# 2      MARIA  200000.0   4/23/1993 2024-08-07 11:17:00  130591   11.858
# 3      JERRY  100000.0    3/4/2005 2024-08-07 13:00:00  138706    9.340
# 4      LARRY  100000.0   1/24/1998 2024-08-07 16:47:00  101005    1.389
# ..       ...       ...         ...                 ...     ...      ...
# 995    HENRY       NaN  11/23/2014 2024-08-07 06:09:00  132484   16.655
# 996  PHILLIP  100000.0   1/31/1984 2024-08-07 06:30:00   42393   19.675
# 997  RUSSELL  100000.0   5/20/2013 2024-08-07 12:39:00   96915    1.421
# 998    LARRY  100000.0   4/20/2013 2024-08-07 16:45:00   60501   11.985
# 999   ALBERT  100000.0   5/15/2012 2024-08-07 18:24:00  129950   10.169
#
#     Senior Management
# 0                True
# 1                True
# 2               False
# ...

# %%
df['Name'] = df['Name'].str.lower()

# %%
df
# Out:
#         Name    Gender  Start Date     Last Login Time  Salary  Bonus %  \
# 0    douglas  100000.0    8/6/1993 2024-08-07 12:42:00   97309    6.945
# 1     thomas  100000.0   3/31/1996 2024-08-07 06:53:00   61934    4.170
# 2      maria  200000.0   4/23/1993 2024-08-07 11:17:00  130591   11.858
# 3      jerry  100000.0    3/4/2005 2024-08-07 13:00:00  138706    9.340
# 4      larry  100000.0   1/24/1998 2024-08-07 16:47:00  101005    1.389
# ..       ...       ...         ...                 ...     ...      ...
# 995    henry       NaN  11/23/2014 2024-08-07 06:09:00  132484   16.655
# 996  phillip  100000.0   1/31/1984 2024-08-07 06:30:00   42393   19.675
# 997  russell  100000.0   5/20/2013 2024-08-07 12:39:00   96915    1.421
# 998    larry  100000.0   4/20/2013 2024-08-07 16:45:00   60501   11.985
# 999   albert  100000.0   5/15/2012 2024-08-07 18:24:00  129950   10.169
#
#     Senior Management
# 0                True
# 1                True
# 2               False
# ...

# %%
df[df['Bonus %']>8]
# Out:
#         Name    Gender  Start Date     Last Login Time  Salary  Bonus %  \
# 2      maria  200000.0   4/23/1993 2024-08-07 11:17:00  130591   11.858
# 3      jerry  100000.0    3/4/2005 2024-08-07 13:00:00  138706    9.340
# 5     dennis  100000.0   4/18/1987 2024-08-07 01:35:00  115164   10.125
# 6       ruby  200000.0   8/17/1987 2024-08-07 16:20:00   65477   10.012
# 7        NaN  200000.0   7/20/2015 2024-08-07 10:43:00   45907   11.598
# ..       ...       ...         ...                 ...     ...      ...
# 993     tina  200000.0   5/15/1997 2024-08-07 15:53:00   56451   19.040
# 995    henry       NaN  11/23/2014 2024-08-07 06:09:00  132484   16.655
# 996  phillip  100000.0   1/31/1984 2024-08-07 06:30:00   42393   19.675
# 998    larry  100000.0   4/20/2013 2024-08-07 16:45:00   60501   11.985
# 999   albert  100000.0   5/15/2012 2024-08-07 18:24:00  129950   10.169
#
#     Senior Management
# 2               False
# 3                True
# 5               False
# ...

# %%
df[head]
